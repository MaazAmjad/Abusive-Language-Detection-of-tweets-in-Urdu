# %%
import numpy as np
import pandas as pd
# Import adjustText, initialize list of texts
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
import itertools
import os
import csv
import re

# %%
dataset_path = "dataset.csv"

# %%
df = pd.read_csv(dataset_path, usecols=['Tweets', 'Positive', 'Negative'])

# %%
df.head()
# Out:
#                                               Tweets Positive Negative
# 0                            کمینی منہ بند رکھ اپنا       yes      NaN
# 1   تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...      NaN       no
# 2   گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...      NaN       no
# 3                           ہو گی بولتی بند گندی رن       yes      NaN
# 4   مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...      NaN       no

# %%
#print(df.shape)
rows,col = df.shape
print(rows)
print(col)
# Out:
# 3499
# 3

# %%
df['word_count'] = df['Tweets'].apply(lambda x: len(str(x).split(" ")))

# %%
df[['Tweets','word_count']].head()
# Out:
#                                               Tweets  word_count
# 0                            کمینی منہ بند رکھ اپنا            7
# 1   تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...          27
# 2   گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...          29
# 3                           ہو گی بولتی بند گندی رن            8
# 4   مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...          19

# %%
df
# Out:
#                                                  Tweets Positive Negative  \
# 0                               کمینی منہ بند رکھ اپنا       yes      NaN
# 1      تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...      NaN       no
# 2      گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...      NaN       no
# 3                              ہو گی بولتی بند گندی رن       yes      NaN
# 4      مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...      NaN       no
# ...                                                 ...      ...      ...
# 3494  از لحاظ جغرافیایی تحت تاثیر ابر های سیل زا و ک...      NaN       no
# 3495  انقدر تباه شدم دارم تو یوتوب لایو کنسرت تتلو ر...      NaN       no
# 3496         انگریزی کی ایک کہاوت ہے۔جس کا ترجمہ یہ ہے       NaN       no
# 3497  عمران سرکار کا ایک سالمعیشت تباہ قرضوں کے انبا...      NaN       no
# 3498         عمران سرکار کا ایک سال مکمل ہو گیا ہے او…       NaN       no
#
#       word_count
# 0              7
# 1             27
# 2             29
# 3              8
# 4             19
# ...          ...
# 3494          18
# 3495          12
# 3496          10
# 3497          15
# 3498          11
#
# [3499 rows x 4 columns]

# %%
df['char_count'] = df['Tweets'].str.len() ## this also includes spaces

# %%
df
# Out:
#                                                  Tweets Positive Negative  \
# 0                               کمینی منہ بند رکھ اپنا       yes      NaN
# 1      تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...      NaN       no
# 2      گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...      NaN       no
# 3                              ہو گی بولتی بند گندی رن       yes      NaN
# 4      مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...      NaN       no
# ...                                                 ...      ...      ...
# 3494  از لحاظ جغرافیایی تحت تاثیر ابر های سیل زا و ک...      NaN       no
# 3495  انقدر تباه شدم دارم تو یوتوب لایو کنسرت تتلو ر...      NaN       no
# 3496         انگریزی کی ایک کہاوت ہے۔جس کا ترجمہ یہ ہے       NaN       no
# 3497  عمران سرکار کا ایک سالمعیشت تباہ قرضوں کے انبا...      NaN       no
# 3498         عمران سرکار کا ایک سال مکمل ہو گیا ہے او…       NaN       no
#
#       word_count  char_count
# 0              7          24
# 1             27         106
# 2             29         110
# 3              8          25
# 4             19          67
# ...          ...         ...
# 3494          18          81
# 3495          12          55
# 3496          10          42
# 3497          15          70
# 3498          11          42
#
# [3499 rows x 5 columns]

# %%
df[['Tweets','char_count']].head()
# Out:
#                                               Tweets  char_count
# 0                            کمینی منہ بند رکھ اپنا           24
# 1   تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...         106
# 2   گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...         110
# 3                           ہو گی بولتی بند گندی رن           25
# 4   مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...          67

# %%
df
# Out:
#                                                  Tweets Positive Negative  \
# 0                               کمینی منہ بند رکھ اپنا       yes      NaN
# 1      تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...      NaN       no
# 2      گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...      NaN       no
# 3                              ہو گی بولتی بند گندی رن       yes      NaN
# 4      مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...      NaN       no
# ...                                                 ...      ...      ...
# 3494  از لحاظ جغرافیایی تحت تاثیر ابر های سیل زا و ک...      NaN       no
# 3495  انقدر تباه شدم دارم تو یوتوب لایو کنسرت تتلو ر...      NaN       no
# 3496         انگریزی کی ایک کہاوت ہے۔جس کا ترجمہ یہ ہے       NaN       no
# 3497  عمران سرکار کا ایک سالمعیشت تباہ قرضوں کے انبا...      NaN       no
# 3498         عمران سرکار کا ایک سال مکمل ہو گیا ہے او…       NaN       no
#
#       word_count  char_count
# 0              7          24
# 1             27         106
# 2             29         110
# 3              8          25
# 4             19          67
# ...          ...         ...
# 3494          18          81
# 3495          12          55
# 3496          10          42
# 3497          15          70
# 3498          11          42
#
# [3499 rows x 5 columns]

# %%
df['avg_word'] = df['Tweets'].apply(lambda x:avg_word(x))
# Out:
# 18
# 80
# 82
# 18
# 49
# 76
# 75
# 61
# 42
# 30
# 66
# 52
# 47
# 45
# 28
# 21
# 19
# 73
# 46
# 11
# 17
# 78
# 39
# 32
# 50
# 62
# 45
# 90
# 40
# 62
# 48
# 53
# 70
# 65
# 40
# 85
# 52
# 67
# 23
# 89
# 57
# 39
# 63
# 20
# 58
# 21
# 37
# 52
# 67
# 56
# 94
# 78
# 57
# 43
# 58
# 24
# 21
# 86
# 24
# 82
# 52
# 98
# 20
# 90
# 75
# 29
# 64
# 47
# 41
# 32
# 30
# 54
# 27
# 25
# 46
# 86
# 70
# 22
# 64
# 61
# 58
# 25
# 10
# 28
# 75
# 72
# 57
# 39
# 77
# 41
# 86
# 84
# 18
# 57
# 31
# 76
# 53
# 59
# 32
# 77
# 70
# 88
# 82
# 73
# 66
# 10
# 35
# 68
# 53
# 89
# 30
# 55
#                                                Tweets Positive Negative  \
# 0                             کمینی منہ بند رکھ اپنا       yes      NaN
# 3                            ہو گی بولتی بند گندی رن       yes      NaN
# 7    تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...      yes      NaN
# 10  اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...      yes      NaN
# 14              تیری بہن کی تو بولتی بند ہوئی پڑی ہے       yes      NaN
#
#     word_count  char_count  avg_word
# 0            7          24  3.600000
# 3            8          25  3.000000
# 7           17          77  4.066667
# 10          24          89  3.000000
# 14          11          38  3.111111

# %%
nowisedf = df.loc[df['Negative'] == 'no']
nowisedf.head()
# Out:
#                                               Tweets Positive Negative  \
# 1   تیری ماں کے یار مودی کی بھی گانڈ مارے گے اور ...      NaN       no
# 2   گورایا تیری ماں کو لن دینے کے لیے مجھے موقع م...      NaN       no
# 4   مریم کی گانڈ آج رات خان مارے گا پھر توں ماموں...      NaN       no
# 5   مریم کی گانڈ میں مرچیں دیں گے آج رات اور پھر ...      NaN       no
# 6  اس کنجھر خسرے کی سر عام روڈ پر گانڈ ماری چاہیے...      NaN       no
#
#    word_count  char_count  avg_word
# 1          27         106  3.200000
# 2          29         110  3.153846
# 4          19          67  3.062500
# 5          26         101  3.166667
# 6          23          97  3.571429

# %%
yeswisedf['word_count'] = yeswisedf['Tweets'].apply(lambda x: len(str(x).split()))
yeswisedf
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                  Tweets Positive Negative  \
# 0                               کمینی منہ بند رکھ اپنا       yes      NaN
# 3                              ہو گی بولتی بند گندی رن       yes      NaN
# 7      تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...      yes      NaN
# 10    اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...      yes      NaN
# 14                تیری بہن کی تو بولتی بند ہوئی پڑی ہے       yes      NaN
# ...                                                 ...      ...      ...
# 3453                                تیری موری میں ڈالوں      yes      NaN
# 3454                                  ٹانگوں کے درمیان       yes      NaN
# 3455                                                ممے      yes      NaN
# 3456                                              بوببز      yes      NaN
# 3457                                 تیرے وڈے وڈے فروٹر      yes      NaN
#
#       word_count  char_count  avg_word
# 0              5          24  3.600000
# 3              6          25  3.000000
# 7             15          77  4.066667
# 10            22          89  3.000000
# 14             9          38  3.111111
# ...          ...         ...       ...
# 3453           4          19  4.000000
# 3454           3          17  4.666667
# 3455           1           3  3.000000
# 3456           1           5  5.000000
# 3457           4          18  3.750000
#
# [1750 rows x 6 columns]

# %%
yeswisedf[['Tweets','word_count']].head()
# Out:
#                                                Tweets  word_count
# 0                             کمینی منہ بند رکھ اپنا            5
# 3                            ہو گی بولتی بند گندی رن            6
# 7    تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...          15
# 10  اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...          22
# 14              تیری بہن کی تو بولتی بند ہوئی پڑی ہے            9

# %%
yeswisedf['char_count'] = yeswisedf['Tweets'].str.len() ## this also includes spaces
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yeswisedf[['Tweets','char_count']].head()
# Out:
#                                                Tweets  char_count
# 0                             کمینی منہ بند رکھ اپنا           24
# 3                            ہو گی بولتی بند گندی رن           25
# 7    تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...          77
# 10  اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...          89
# 14              تیری بہن کی تو بولتی بند ہوئی پڑی ہے           38

# %%
yeswisedf.shape
yes_rows,yes_col=yeswisedf.shape

# %%
def avg_word(sentence):
    words = sentence.split()
    print(sum(len(word) for word in words))
    return (sum(len(word) for word in words)/yes_rows)

# %%
yeswisedf['avg_word'] = yeswisedf['Tweets'].apply(lambda x: avg_word(x))
yeswisedf[['Tweets','avg_word']].head()
# Out:
# 18
# 18
# 61
# 66
# 28
# 21
# 19
# 11
# 17
# 32
# 62
# 45
# 40
# 48
# 53
# 67
# 23
# 39
# 63
# 21
# 67
# 56
# 78
# 57
# 58
# 21
# 86
# 82
# 98
# 20
# 75
# 64
# 41
# 32
# 30
# 25
# 10
# 28
# 39
# 77
# 18
# 57
# 76
# 59
# 32
# 66
# 89
# 55
# 68
# 60
# 146
# 46
# 78
# 124
# 32
# 80
# 82
# 56
# 35
# 50
# 33
# 39
# 43
# 77
# 45
# 72
# 49
# 68
# 75
# 36
# 42
# 30
# 25
# 52
# 47
# 30
# 73
# 46
# 67
# 78
# 81
# 39
# 50
# 90
# 64
# 69
# 65
# 40
# 79
# 52
# 31
# 88
# 52
# 50
# 56
# 20
# 58
# 37
# 58
# 94
# 52
# 49
# 69
# 45
# 37
# 71
# 79
# 31
# 57
# 47
# 70
# 59
# 42
# 59
# 26
# 67
# 31
# 65
# 84
# 66
# 79
# 70
# 70
# 61
# 16
# 60
# 80
# 23
# 78
# 31
# 100
# 36
# 92
# 24
# 15
# 69
# 131
# 91
# 75
# 15
# 86
# 95
# 86
# 42
# 72
# 34
# 64
# 52
# 71
# 47
# 64
# 93
# 28
# 15
# 29
# 27
# 83
# 82
# 26
# 33
# 43
# 22
# 28
# 71
# 12
# 27
# 74
# 87
# 71
# 28
# 42
# 91
# 84
# 72
# 16
# 38
# 28
# 66
# 69
# 51
# 16
# 80
# 75
# 36
# 15
# 35
# 62
# 39
# 13
# 74
# 66
# 48
# 73
# 20
# 46
# 60
# 48
# 34
# 49
# 22
# 81
# 30
# 50
# 57
# 41
# 61
# 57
# 87
# 54
# 26
# 26
# 65
# 77
# 24
# 28
# 68
# 52
# 87
# 60
# 57
# 63
# 71
# 16
# 61
# 65
# 63
# 48
# 87
# 27
# 54
# 68
# 25
# 83
# 83
# 91
# 61
# 62
# 81
# 28
# 16
# 75
# 33
# 88
# 81
# 34
# 28
# 82
# 74
# 50
# 32
# 36
# 57
# 49
# 40
# 15
# 57
# 59
# 32
# 75
# 56
# 27
# 55
# 77
# 68
# 60
# 147
# 46
# 78
# 44
# 32
# 80
# 82
# 56
# 35
# 50
# 33
# 40
# 43
# 77
# 45
# 72
# 49
# 76
# 75
# 36
# 42
# 30
# 25
# 52
# 47
# 45
# 30
# 73
# 46
# 67
# 78
# 85
# 39
# 51
# 90
# 78
# 8
# 53
# 25
# 8
# 85
# 33
# 19
# 84
# 59
# 17
# 17
# 85
# 14
# 51
# 26
# 19
# 14
# 13
# 39
# 25
# 84
# 21
# 29
# 43
# 42
# 14
# 28
# 55
# 57
# 43
# 54
# 41
# 32
# 55
# 64
# 41
# 69
# 88
# 27
# 77
# 34
# 62
# 27
# 36
# 92
# 82
# 32
# 75
# 40
# 32
# 42
# 37
# 54
# 27
# 59
# 26
# 67
# 22
# 35
# 54
# 66
# 45
# 45
# 31
# 20
# 69
# 96
# 31
# 65
# 67
# 54
# 38
# 63
# 50
# 56
# 22
# 39
# 57
# 71
# 50
# 49
# 25
# 35
# 55
# 67
# 62
# 76
# 86
# 63
# 24
# 42
# 56
# 65
# 55
# 64
# 44
# 12
# 31
# 27
# 65
# 48
# 30
# 69
# 68
# 44
# 55
# 89
# 68
# 38
# 57
# 57
# 25
# 70
# 85
# 31
# 65
# 81
# 35
# 60
# 25
# 72
# 65
# 82
# 36
# 80
# 68
# 65
# 56
# 62
# 22
# 91
# 19
# 79
# 50
# 51
# 11
# 63
# 91
# 22
# 29
# 43
# 19
# 49
# 17
# 24
# 62
# 75
# 16
# 28
# 50
# 60
# 47
# 18
# 42
# 41
# 26
# 21
# 18
# 50
# 57
# 78
# 86
# 61
# 66
# 33
# 42
# 62
# 80
# 86
# 32
# 17
# 63
# 75
# 89
# 43
# 61
# 32
# 31
# 22
# 69
# 26
# 66
# 30
# 27
# 46
# 63
# 35
# 74
# 57
# 48
# 64
# 65
# 43
# 48
# 13
# 55
# 17
# 71
# 34
# 17
# 69
# 22
# 44
# 60
# 73
# 52
# 17
# 51
# 9
# 68
# 35
# 70
# 67
# 29
# 12
# 34
# 44
# 99
# 76
# 30
# 32
# 42
# 57
# 42
# 31
# 61
# 52
# 28
# 16
# 31
# 39
# 46
# 45
# 63
# 60
# 44
# 62
# 19
# 16
# 37
# 61
# 30
# 57
# 35
# 93
# 76
# 53
# 23
# 47
# 69
# 74
# 34
# 59
# 36
# 27
# 11
# 69
# 70
# 84
# 68
# 85
# 69
# 37
# 38
# 58
# 91
# 81
# 20
# 61
# 37
# 70
# 91
# 77
# 60
# 20
# 68
# 46
# 53
# 61
# 17
# 57
# 29
# 26
# 24
# 46
# 19
# 26
# 54
# 23
# 14
# 5
# 5
# 5
# 16
# 14
# 3
# 5
# 15
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                Tweets  avg_word
# 0                             کمینی منہ بند رکھ اپنا   0.010286
# 3                            ہو گی بولتی بند گندی رن   0.010286
# 7    تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...  0.034857
# 10  اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...  0.037714
# 14              تیری بہن کی تو بولتی بند ہوئی پڑی ہے   0.016000

# %%
df_row = pd.concat([yeswisedf['Tweets'], nowisedf['Tweets']])
df_row
# Out:
# 0                                 کمینی منہ بند رکھ اپنا
# 3                                ہو گی بولتی بند گندی رن
# 7        تمہاری سنتا کون ہے خامخوا بکواس بولتی بند کرو...
# 10      اس کی بولتی بند ھے آج کل کیونکہ اس کے اوپر سے ...
# 14                  تیری بہن کی تو بولتی بند ہوئی پڑی ہے
#                               ...
# 3494    از لحاظ جغرافیایی تحت تاثیر ابر های سیل زا و ک...
# 3495    انقدر تباه شدم دارم تو یوتوب لایو کنسرت تتلو ر...
# 3496           انگریزی کی ایک کہاوت ہے۔جس کا ترجمہ یہ ہے
# 3497    عمران سرکار کا ایک سالمعیشت تباہ قرضوں کے انبا...
# 3498           عمران سرکار کا ایک سال مکمل ہو گیا ہے او…
# Name: Tweets, Length: 3499, dtype: object

# %%
print("Total Dataset:" + str(len(df_row)))
print("yes class:" + str(len(yeswisedf)))
print("no class:" + str(len(nowisedf)))
# Out:
# Total Dataset:3499
# yes class:1750
# no class:1749

# %% [markdown]
# #### Numan: Write a function to calculate average words in a tweet

# %%
def Load_Dataset():    
   
       

        
        
        
       
        
        
        
        
    
        
        
        
        
      
        
        

        
        
        
    
        
        
        
        
        Number_OF_Documents = rows + 1
        #Number_OF_Documents = len(yeswisedf) + len(nowisedf)
        Number_OF_POSITIVE_SAMPLES = len(yeswisedf)
        Number_OF_NEGATIVE_SAMPLES = len(nowisedf)
        
        
        
        y_train = np.empty(Number_OF_Documents-1)
       
        for i in range(0,Number_OF_Documents-1):
            if i < Number_OF_POSITIVE_SAMPLES - 1:
                y_train[i] = 1
            else:
                y_train[i] = 0
        
        
        i = 0
        #for index,row in df[:Number_OF_Documents].iterrows():
        for index,row in df.iterrows():
            positive = row['Positive']
            negative = row['Negative']
        
            
            if positive == "yes":
                y_train[i] = 1
            elif negative == "no":
                y_train[i] = 0
            else:
                y_train[i] = 0
            i = i + 1
            
            
        
        
        keywords_dictionary = []
        sentences_corpus = []
        #for index,row in df.iterrows(): 
        for index,row in df[:Number_OF_Documents].iterrows():
                text = str(row['Tweets'])
                
                sentences_corpus.append(text)
                list_of_words = text.split(" ")
                keywords_dictionary.append(list_of_words)
            
        
        
        print(keywords_dictionary[0])
        #print(sentences_corpus[1])
        
        
        vocab = []
        for kl in keywords_dictionary: 
            for w in kl:
                vocab.append(str(w))
            
        
        
        
        corpus = []
        for kl in sentences_corpus: 
            corpus = corpus + kl.split(',')
        
        
    
        if words:
            vectorizer = CountVectorizer(ngram_range=_ngram_range, max_features=_max_features)
            Count_Vect = vectorizer.fit_transform(vocab)
            #print(vectorizer.get_feature_names())
            #print(X.toarray())
        else:
            vectorizer = CountVectorizer(ngram_range=_ngram_range, token_pattern = r"(?u)\b\w+\b",  analyzer='char')
            Count_Vect = vectorizer.fit_transform(vocab)
            #print(vectorizer.get_feature_names())

                
                
        vectorizer = TfidfVectorizer(ngram_range=_ngram_range,max_features=_max_features) # You can still specify n-grams here.
        X = vectorizer.fit_transform(corpus).toarray()   
            
            
            
        print( "Shape of final Ngram vector:" + str(X.shape))
        print( "Shape of labels:" + str(y_train.shape))
        xTrain, xTest, yTrain, yTest = train_test_split(X, y_train, test_size = 0.2)   
        return xTrain, xTest, yTrain, yTest, sentences_corpus, keywords_dictionary, y_train
